# %%
import pandas as pd

# %%
df = pd.read_csv("metadata.csv")
df.head()
# Out:
#         isic_id                        attribution copyright_license  \
# 0  ISIC_0079358  Hospital Italiano de Buenos Aires             CC-BY
# 1  ISIC_0086914  Hospital Italiano de Buenos Aires             CC-BY
# 2  ISIC_0088904  Hospital Italiano de Buenos Aires             CC-BY
# 3  ISIC_0094098  Hospital Italiano de Buenos Aires             CC-BY
# 4  ISIC_0095134  Hospital Italiano de Buenos Aires             CC-BY
#
#    age_approx anatom_site_general anatom_site_special benign_malignant  \
# 0        35.0      anterior torso                 NaN           benign
# 1        55.0     upper extremity                 NaN        malignant
# 2        50.0                 NaN                 NaN        malignant
# 3        65.0     posterior torso                 NaN        malignant
# 4        70.0      anterior torso                 NaN        malignant
#
#    concomitant_biopsy   dermoscopic_type             diagnosis  ...  \
# ...

# %%
df.columns
# Out:
# Index(['isic_id', 'attribution', 'copyright_license', 'age_approx',
#        'anatom_site_general', 'anatom_site_special', 'benign_malignant',
#        'concomitant_biopsy', 'dermoscopic_type', 'diagnosis', 'diagnosis_1',
#        'diagnosis_2', 'diagnosis_3', 'diagnosis_confirm_type', 'family_hx_mm',
#        'fitzpatrick_skin_type', 'image_type', 'lesion_id', 'patient_id',
#        'personal_hx_mm', 'sex'],
#       dtype='object')

# %%
df["diagnosis"].unique()
# Out:
# array(['nevus', 'basal cell carcinoma', 'melanoma', 'vascular lesion',
#        'seborrheic keratosis', 'actinic keratosis',
#        'squamous cell carcinoma', 'dermatofibroma', 'solar lentigo',
#        'lichenoid keratosis'], dtype=object)

# %%
df[df['diagnosis'] == "lichenoid keratosis"]
# Out:
#           isic_id                        attribution copyright_license  \
# 531  ISIC_3323494  Hospital Italiano de Buenos Aires             CC-BY
# 755  ISIC_4788959  Hospital Italiano de Buenos Aires             CC-BY
#
#      age_approx anatom_site_general anatom_site_special benign_malignant  \
# 531        80.0     posterior torso                 NaN           benign
# 755        80.0     posterior torso                 NaN           benign
#
#      concomitant_biopsy   dermoscopic_type            diagnosis  ...  \
# 531               False  contact polarized  lichenoid keratosis  ...
# 755               False                NaN  lichenoid keratosis  ...
#
#                          diagnosis_2                   diagnosis_3  \
# 531  Benign epidermal proliferations  Lichen planus like keratosis
# 755  Benign epidermal proliferations  Lichen planus like keratosis
#
#     diagnosis_confirm_type family_hx_mm fitzpatrick_skin_type  \
# ...

# %%
df["age_approx"].unique()
# Out:
# array([35., 55., 50., 65., 70., 30., 80., 75., 40., 85., 45., 60., 20.,
#        25., nan])

# %%
count = df.loc[(df['age_approx'] > 10) & (df['age_approx'] < 50), 'age_approx'].count()
count
# Out:
# np.int64(472)

# %%
import pandas as pd

# Ensure the 'age' column exists and filter rows where age is between 10 and 50
if 'age_approx' in df.columns:
    filtered_df = df[(df['age_approx'] >= 10) & (df['age_approx'] <= 50)]
    # Save the filtered DataFrame to metadata1.csv
    filtered_df.to_csv(r"C:\Users\infor\Programming\DataScience\skindisease\metadata1.csv", index=False)
    print("Filtered DataFrame saved to metadata1.csv")
else:
    print("The 'age' column does not exist in the metadata.")
# Out:
# Filtered DataFrame saved to metadata1.csv

# %%
df1 = pd.read_csv("metadata1.csv")
df1["diagnosis"].unique()
# Out:
# array(['nevus', 'basal cell carcinoma', 'melanoma',
#        'squamous cell carcinoma', 'vascular lesion', 'dermatofibroma',
#        'actinic keratosis', 'seborrheic keratosis', 'solar lentigo'],
#       dtype=object)

# %%
df1
# Out:
#           isic_id                        attribution copyright_license  \
# 0    ISIC_0079358  Hospital Italiano de Buenos Aires             CC-BY
# 1    ISIC_0088904  Hospital Italiano de Buenos Aires             CC-BY
# 2    ISIC_0115851  Hospital Italiano de Buenos Aires             CC-BY
# 3    ISIC_0141408  Hospital Italiano de Buenos Aires             CC-BY
# 4    ISIC_0141681  Hospital Italiano de Buenos Aires             CC-BY
# ..            ...                                ...               ...
# 554  ISIC_9951833  Hospital Italiano de Buenos Aires             CC-BY
# 555  ISIC_9951988  Hospital Italiano de Buenos Aires             CC-BY
# 556  ISIC_9955470  Hospital Italiano de Buenos Aires             CC-BY
# 557  ISIC_9988844  Hospital Italiano de Buenos Aires             CC-BY
# 558  ISIC_9989778  Hospital Italiano de Buenos Aires             CC-BY
#
#      age_approx anatom_site_general anatom_site_special benign_malignant  \
# ...

# %%
df1[df1['diagnosis'] == "nevus"]
# Out:
#           isic_id                        attribution copyright_license  \
# 0    ISIC_0079358  Hospital Italiano de Buenos Aires             CC-BY
# 2    ISIC_0115851  Hospital Italiano de Buenos Aires             CC-BY
# 3    ISIC_0141408  Hospital Italiano de Buenos Aires             CC-BY
# 4    ISIC_0141681  Hospital Italiano de Buenos Aires             CC-BY
# 5    ISIC_0142436  Hospital Italiano de Buenos Aires             CC-BY
# ..            ...                                ...               ...
# 553  ISIC_9944002  Hospital Italiano de Buenos Aires             CC-BY
# 554  ISIC_9951833  Hospital Italiano de Buenos Aires             CC-BY
# 556  ISIC_9955470  Hospital Italiano de Buenos Aires             CC-BY
# 557  ISIC_9988844  Hospital Italiano de Buenos Aires             CC-BY
# 558  ISIC_9989778  Hospital Italiano de Buenos Aires             CC-BY
#
#      age_approx anatom_site_general anatom_site_special benign_malignant  \
# ...

# %%
df2 = pd.read_csv("HAM10000_metadata.csv")
df2.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
df2.columns
# Out:
# Index(['lesion_id', 'image_id', 'dx', 'dx_type', 'age', 'sex', 'localization'], dtype='object')

# %%
df2['dx'].unique()
# Out:
# array(['bkl', 'nv', 'df', 'mel', 'vasc', 'bcc', 'akiec'], dtype=object)

# %%
count = df2.loc[(df2['age'] >=20) & (df2['age'] <= 50), 'age'].count()
count
# Out:
# np.int64(5104)

# %%
import pandas as pd

# Ensure the 'age' column exists and filter rows where age is between 10 and 50
if 'age' in df2.columns:
    filtered_df = df2[(df2['age'] >= 20) & (df2['age'] <= 50)]
    # Save the filtered DataFrame to metadata1.csv
    filtered_df.to_csv(r"C:\Users\infor\Programming\DataScience\skindisease\metadatanew.csv", index=False)
    print("Filtered DataFrame saved to metadatanew.csv")
else:
    print("The 'age' column does not exist in the metadata.")
# Out:
# Filtered DataFrame saved to metadatanew.csv

# %%
new = pd.read_csv("metadatanew.csv")
new
# Out:
#         lesion_id      image_id     dx dx_type   age     sex     localization
# 0     HAM_0002521  ISIC_0027828    bkl   histo  40.0    male  upper extremity
# 1     HAM_0002521  ISIC_0029291    bkl   histo  40.0    male  upper extremity
# 2     HAM_0006574  ISIC_0030698    bkl   histo  40.0    male             back
# 3     HAM_0006574  ISIC_0025567    bkl   histo  40.0    male             back
# 4     HAM_0007409  ISIC_0025076    bkl   histo  50.0    male  upper extremity
# ...           ...           ...    ...     ...   ...     ...              ...
# 5099  HAM_0001036  ISIC_0027588  akiec   histo  50.0  female             face
# 5100  HAM_0004462  ISIC_0027334  akiec   histo  45.0    male            trunk
# 5101  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male          abdomen
# 5102  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male          abdomen
# 5103  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male          abdomen
#
# [5104 rows x 7 columns]

# %%
new['dx'].unique()
# Out:
# array(['bkl', 'df', 'nv', 'mel', 'vasc', 'bcc', 'akiec'], dtype=object)

# %%
new[new['dx'] == "nv"]
# Out:
#         lesion_id      image_id  dx    dx_type   age     sex     localization
# 276   HAM_0000559  ISIC_0024693  nv  follow_up  45.0  female  upper extremity
# 727   HAM_0004932  ISIC_0032212  nv  follow_up  45.0  female             foot
# 728   HAM_0004516  ISIC_0025775  nv  follow_up  45.0  female             neck
# 729   HAM_0007567  ISIC_0031588  nv  follow_up  45.0  female  lower extremity
# 730   HAM_0001940  ISIC_0028502  nv  follow_up  45.0  female          abdomen
# ...           ...           ...  ..        ...   ...     ...              ...
# 5060  HAM_0006283  ISIC_0027924  nv  consensus  20.0    male            chest
# 5061  HAM_0000102  ISIC_0031547  nv  consensus  20.0    male             back
# 5062  HAM_0000102  ISIC_0032221  nv  consensus  20.0    male             back
# 5063  HAM_0005314  ISIC_0030693  nv  consensus  40.0    male             neck
# 5064  HAM_0003322  ISIC_0031649  nv  consensus  50.0  female             face
#
# [4331 rows x 7 columns]

# %%
# df_combined = pd.concat([df1, df2], axis=0, ignore_index=True)

# print(df_combined)

# combine both the dataframe with common columns
# the data is imbalanced, balance it by adding weights etc 
# train again for 30 epochs and check the accuracy
